# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_categorical = pd.read_excel('TRAIN/TRAIN_CATEGORICAL_METADATA.xlsx')
df_matrices = pd.read_csv('TRAIN/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv')
df_quant = pd.read_excel('TRAIN/TRAIN_QUANTITATIVE_METADATA.xlsx')
df_solutions = pd.read_excel('TRAIN/TRAINING_SOLUTIONS.xlsx')

# %%
df_solutions.head(5)
# Out:
#   participant_id  ADHD_Outcome  Sex_F
# 0   UmrK0vMLopoR             1      1
# 1   CPaeQkhcjg7d             1      0
# 2   Nb4EetVPm3gs             1      0
# 3   p4vPhVu91o4b             1      1
# 4   M09PXs7arQ5E             1      1

# %%
df_quant.head(10)
# Out:
#   participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0   UmrK0vMLopoR          40.00                    13               3
# 1   CPaeQkhcjg7d         -94.47                    14               3
# 2   Nb4EetVPm3gs         -46.67                    14               4
# 3   p4vPhVu91o4b         -26.68                    10               5
# 4   M09PXs7arQ5E           0.00                    14               5
# 5   tBGXkEdv2cp7          83.34                     2               5
# 6   DgRP31gu21O9          94.47                    14               3
# 7   ClMA0FwvFgLY          60.00                    14               3
# 8   NVUkahaJ6fhf          73.34                    14               4
# 9   u0JiZgdGuYvh          66.67                    14               6
#
#    APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0              10               47               13              11
# ...

# %%
df_quant.dtypes
# Out:
# participant_id                 object
# EHQ_EHQ_Total                 float64
# ColorVision_CV_Score            int64
# APQ_P_APQ_P_CP                  int64
# APQ_P_APQ_P_ID                  int64
# APQ_P_APQ_P_INV                 int64
# APQ_P_APQ_P_OPD                 int64
# APQ_P_APQ_P_PM                  int64
# APQ_P_APQ_P_PP                  int64
# SDQ_SDQ_Conduct_Problems        int64
# SDQ_SDQ_Difficulties_Total      int64
# SDQ_SDQ_Emotional_Problems      int64
# SDQ_SDQ_Externalizing           int64
# SDQ_SDQ_Generating_Impact       int64
# SDQ_SDQ_Hyperactivity           int64
# SDQ_SDQ_Internalizing           int64
# SDQ_SDQ_Peer_Problems           int64
# SDQ_SDQ_Prosocial               int64
# MRI_Track_Age_at_Scan         float64
# dtype: object

# %%
df_quant.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count    1213.000000           1213.000000     1213.000000     1213.000000
# mean       58.876917             13.164880        3.781533       13.205276
# std        49.855501              2.780624        1.376700        3.811772
# min      -100.000000              0.000000        0.000000        0.000000
# 25%        45.600000             14.000000        3.000000       11.000000
# 50%        76.670000             14.000000        3.000000       13.000000
# 75%        93.400000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count      1213.000000      1213.000000     1213.000000     1213.000000
# mean         39.374279        17.785655       16.393240       25.246496
# std           6.245928         3.764112        5.376994        3.950529
# ...

# %%
df_quant.isnull().sum()
# Out:
# participant_id                  0
# EHQ_EHQ_Total                   0
# ColorVision_CV_Score            0
# APQ_P_APQ_P_CP                  0
# APQ_P_APQ_P_ID                  0
# APQ_P_APQ_P_INV                 0
# APQ_P_APQ_P_OPD                 0
# APQ_P_APQ_P_PM                  0
# APQ_P_APQ_P_PP                  0
# SDQ_SDQ_Conduct_Problems        0
# SDQ_SDQ_Difficulties_Total      0
# SDQ_SDQ_Emotional_Problems      0
# SDQ_SDQ_Externalizing           0
# SDQ_SDQ_Generating_Impact       0
# SDQ_SDQ_Hyperactivity           0
# SDQ_SDQ_Internalizing           0
# SDQ_SDQ_Peer_Problems           0
# SDQ_SDQ_Prosocial               0
# MRI_Track_Age_at_Scan         360
# dtype: int64

# %%
df_quant_1 = df_quant.dropna(subset = ['MRI_Track_Age_at_Scan'])

# %%
df_quant_1.isnull().sum()
# Out:
# participant_id                0
# EHQ_EHQ_Total                 0
# ColorVision_CV_Score          0
# APQ_P_APQ_P_CP                0
# APQ_P_APQ_P_ID                0
# APQ_P_APQ_P_INV               0
# APQ_P_APQ_P_OPD               0
# APQ_P_APQ_P_PM                0
# APQ_P_APQ_P_PP                0
# SDQ_SDQ_Conduct_Problems      0
# SDQ_SDQ_Difficulties_Total    0
# SDQ_SDQ_Emotional_Problems    0
# SDQ_SDQ_Externalizing         0
# SDQ_SDQ_Generating_Impact     0
# SDQ_SDQ_Hyperactivity         0
# SDQ_SDQ_Internalizing         0
# SDQ_SDQ_Peer_Problems         0
# SDQ_SDQ_Prosocial             0
# MRI_Track_Age_at_Scan         0
# dtype: int64

# %%
df_quant_1.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count     853.000000            853.000000      853.000000      853.000000
# mean       59.623036             13.128957        3.808910       13.301290
# std        48.394417              2.844114        1.407497        3.810901
# min      -100.000000              0.000000        0.000000        0.000000
# 25%        46.670000             14.000000        3.000000       11.000000
# 50%        74.470000             14.000000        3.000000       13.000000
# 75%        94.470000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count       853.000000       853.000000      853.000000      853.000000
# mean         39.370457        17.746776       16.534584       25.199297
# std           6.136833         3.710362        5.483461        3.913099
# ...

# %%
df_quant_with_sols = pd.merge(df_quant, df_solutions, on ='participant_id', how ='inner')

# %%
df_quant_with_sols.head(10)
# Out:
#   participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0   UmrK0vMLopoR          40.00                    13               3
# 1   CPaeQkhcjg7d         -94.47                    14               3
# 2   Nb4EetVPm3gs         -46.67                    14               4
# 3   p4vPhVu91o4b         -26.68                    10               5
# 4   M09PXs7arQ5E           0.00                    14               5
# 5   tBGXkEdv2cp7          83.34                     2               5
# 6   DgRP31gu21O9          94.47                    14               3
# 7   ClMA0FwvFgLY          60.00                    14               3
# 8   NVUkahaJ6fhf          73.34                    14               4
# 9   u0JiZgdGuYvh          66.67                    14               6
#
#    APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0              10               47               13              11
# ...

# %%
df_quant_with_sols.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count    1213.000000           1213.000000     1213.000000     1213.000000
# mean       58.876917             13.164880        3.781533       13.205276
# std        49.855501              2.780624        1.376700        3.811772
# min      -100.000000              0.000000        0.000000        0.000000
# 25%        45.600000             14.000000        3.000000       11.000000
# 50%        76.670000             14.000000        3.000000       13.000000
# 75%        93.400000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count      1213.000000      1213.000000     1213.000000     1213.000000
# mean         39.374279        17.785655       16.393240       25.246496
# std           6.245928         3.764112        5.376994        3.950529
# ...

# %%
df_quant_with_sols_1 = df_quant_with_sols.drop('participant_id',axis=1)

# %%
df_quant_with_sols_1.head(2)
# Out:
#    EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# 0          40.00                    13               3              10
# 1         -94.47                    14               3              13
#
#    APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# 0               47               13              11              28
# 1               34               18              23              30
#
#    SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# 0                         0                           6
# 1                         0                          18
#
#    SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# 0                           1                      5
# 1                           6                      8
#
#    SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Internalizing  \
# 0                          0                      5                      1
# ...

# %%
#correlation
correlation_matrix = df_quant_with_sols_1.corr(method='pearson')  # Pearson by default
print(correlation_matrix)
# Out:
#                             EHQ_EHQ_Total  ColorVision_CV_Score  \
# EHQ_EHQ_Total                    1.000000              0.027679
# ColorVision_CV_Score             0.027679              1.000000
# APQ_P_APQ_P_CP                  -0.013414              0.066965
# APQ_P_APQ_P_ID                   0.019131              0.022960
# APQ_P_APQ_P_INV                  0.033819              0.007465
# APQ_P_APQ_P_OPD                 -0.012423              0.023402
# APQ_P_APQ_P_PM                   0.049200             -0.013446
# APQ_P_APQ_P_PP                   0.020321              0.029796
# SDQ_SDQ_Conduct_Problems        -0.051240              0.016444
# SDQ_SDQ_Difficulties_Total      -0.054827              0.000335
# SDQ_SDQ_Emotional_Problems      -0.034221              0.010199
# SDQ_SDQ_Externalizing           -0.028900              0.005308
# SDQ_SDQ_Generating_Impact       -0.014712              0.051282
# SDQ_SDQ_Hyperactivity           -0.005902             -0.003932
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Standardization
scaler = StandardScaler()
np_quant_with_sols_1_scaled_std = scaler.fit_transform(df_quant_with_sols_1)

# %%
np_quant_with_sols_1_scaled_std
# Out:
# array([[-0.37878875, -0.05932067, -0.56792029, ...,         nan,
#          0.6780023 ,  1.38414789],
#        [-3.07709608,  0.30045921, -0.56792029, ...,         nan,
#          0.6780023 , -0.72246615],
#        [-2.11792979,  0.30045921,  0.15875409, ..., -0.92986757,
#          0.6780023 , -0.72246615],
#        ...,
#        [-0.84673347,  0.30045921, -0.56792029, ...,         nan,
#         -1.47492124,  1.38414789],
#        [-0.10990113,  0.30045921, -0.56792029, ...,  0.26091938,
#         -1.47492124, -0.72246615],
#        [-2.34126705,  0.30045921,  0.88542847, ...,  0.4176463 ,
#         -1.47492124, -0.72246615]], shape=(1213, 20))

# %%
df_quant_with_sols_1_scaled_std = pd.DataFrame(np_quant_with_sols_1_scaled_std)

# %%
df_quant_with_sols_1_scaled_std.columns = df_quant_with_sols_1.columns

# %%
df_quant_with_sols_1_scaled_std.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count   1.213000e+03          1.213000e+03    1.213000e+03    1.213000e+03
# mean    8.347266e-17         -8.786596e-17    3.514638e-17    1.523010e-16
# std     1.000412e+00          1.000412e+00    1.000412e+00    1.000412e+00
# min    -3.188062e+00         -4.736459e+00   -2.747943e+00   -3.465769e+00
# 25%    -2.664178e-01          3.004592e-01   -5.679203e-01   -5.787821e-01
# 50%     3.570403e-01          3.004592e-01   -5.679203e-01   -5.387542e-02
# 75%     6.927485e-01          3.004592e-01    1.587541e-01    7.334846e-01
# max     8.251857e-01          3.004592e-01    5.972149e+00    3.882925e+00
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count     1.213000e+03     1.213000e+03    1.213000e+03    1.213000e+03
# mean      3.690370e-16     3.983257e-16   -6.736390e-17    2.489536e-16
# std       1.000412e+00     1.000412e+00    1.000412e+00    1.000412e+00
# ...

# %%
#correlation
correlation_matrix = df_quant_with_sols_1_scaled_std.corr(method='pearson')  # Pearson by default
print(correlation_matrix)
# Out:
#                             EHQ_EHQ_Total  ColorVision_CV_Score  \
# EHQ_EHQ_Total                    1.000000              0.027679
# ColorVision_CV_Score             0.027679              1.000000
# APQ_P_APQ_P_CP                  -0.013414              0.066965
# APQ_P_APQ_P_ID                   0.019131              0.022960
# APQ_P_APQ_P_INV                  0.033819              0.007465
# APQ_P_APQ_P_OPD                 -0.012423              0.023402
# APQ_P_APQ_P_PM                   0.049200             -0.013446
# APQ_P_APQ_P_PP                   0.020321              0.029796
# SDQ_SDQ_Conduct_Problems        -0.051240              0.016444
# SDQ_SDQ_Difficulties_Total      -0.054827              0.000335
# SDQ_SDQ_Emotional_Problems      -0.034221              0.010199
# SDQ_SDQ_Externalizing           -0.028900              0.005308
# SDQ_SDQ_Generating_Impact       -0.014712              0.051282
# SDQ_SDQ_Hyperactivity           -0.005902             -0.003932
# ...

# %%
# Create a heatmap
plt.figure(figsize=(10, 8))  # Increase figure size to fit the labels
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Rotate the column labels (slant them by 45 degrees)
plt.xticks(rotation=45, ha='right')  # Slant column labels by 45 degrees
plt.yticks(rotation=0)  # Keep y-axis labels upright (optional)

# Adjust layout to ensure everything fits
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Min-Max Scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
np_quant_with_sols_1_scaled_minmax = scaler.fit_transform(df_quant_with_sols_1)

# %%
df_quant_with_sols_1_scaled_minmax = pd.DataFrame(np_quant_with_sols_1_scaled_minmax)

# %%
df_quant_with_sols_1_scaled_minmax.columns = df_quant_with_sols_1.columns

# %%
df_quant_with_sols_1_scaled_minmax.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count    1213.000000           1213.000000     1213.000000     1213.000000
# mean        0.794385              0.940349        0.315128        0.471617
# std         0.249278              0.198616        0.114725        0.136135
# min         0.000000              0.000000        0.000000        0.000000
# 25%         0.728000              1.000000        0.250000        0.392857
# 50%         0.883350              1.000000        0.250000        0.464286
# 75%         0.967000              1.000000        0.333333        0.571429
# max         1.000000              1.000000        1.000000        1.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count      1213.000000      1213.000000     1213.000000     1213.000000
# mean          0.787486         0.635202        0.443061        0.841550
# std           0.124919         0.134433        0.145324        0.131684
# ...

# %%
#correlation
correlation_matrix = df_quant_with_sols_1_scaled_minmax.corr(method='pearson')  # Pearson by default
print(correlation_matrix)
# Out:
#                             EHQ_EHQ_Total  ColorVision_CV_Score  \
# EHQ_EHQ_Total                    1.000000              0.027679
# ColorVision_CV_Score             0.027679              1.000000
# APQ_P_APQ_P_CP                  -0.013414              0.066965
# APQ_P_APQ_P_ID                   0.019131              0.022960
# APQ_P_APQ_P_INV                  0.033819              0.007465
# APQ_P_APQ_P_OPD                 -0.012423              0.023402
# APQ_P_APQ_P_PM                   0.049200             -0.013446
# APQ_P_APQ_P_PP                   0.020321              0.029796
# SDQ_SDQ_Conduct_Problems        -0.051240              0.016444
# SDQ_SDQ_Difficulties_Total      -0.054827              0.000335
# SDQ_SDQ_Emotional_Problems      -0.034221              0.010199
# SDQ_SDQ_Externalizing           -0.028900              0.005308
# SDQ_SDQ_Generating_Impact       -0.014712              0.051282
# SDQ_SDQ_Hyperactivity           -0.005902             -0.003932
# ...

# %%
# Create a heatmap
plt.figure(figsize=(10, 8))  # Increase figure size to fit the labels
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Rotate the column labels (slant them by 45 degrees)
plt.xticks(rotation=45, ha='right')  # Slant column labels by 45 degrees
plt.yticks(rotation=0)  # Keep y-axis labels upright (optional)

# Adjust layout to ensure everything fits
plt.tight_layout()

# Display the plot
plt.show()

# %%
df_matrices_with_sols = pd.merge(df_matrices, df_solutions, on ='participant_id', how ='inner')

# %%
df_matrices_with_sols
# Out:
#      participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0      70z8Q2xdTXM3          0.093473          0.146902          0.067893
# 1      WHWymJu6zNZi          0.029580          0.179323          0.112933
# 2      4PAQp1M6EyAo         -0.051580          0.139734          0.068295
# 3      obEacy4Of68I          0.016273          0.204702          0.115980
# 4      s7WzzDcmDOhF          0.065771          0.098714          0.097604
# ...             ...               ...               ...               ...
# 1208   kTurROKp5YHQ          0.022932          0.024830         -0.006514
# 1209   FCRyMz9O6yCq          0.047078          0.135955          0.144366
# 1210   vm2P1hmAY1hl          0.094541          0.145280          0.061964
# 1211   OFxvN8lnw21w         -0.001533          0.128562          0.045000
# 1212   9gpepMI9sj5q         -0.115224          0.147713          0.083183
#
#       0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# ...

# %%
df_categorical_with_sols = pd.merge(df_categorical, df_quant, on ='participant_id', how ='inner')

# %%
df_categorical_with_sols
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      UmrK0vMLopoR                     2016                       1
# 1      CPaeQkhcjg7d                     2019                       3
# 2      Nb4EetVPm3gs                     2016                       1
# 3      p4vPhVu91o4b                     2018                       3
# 4      M09PXs7arQ5E                     2019                       3
# ...             ...                      ...                     ...
# 1208   Atx7oub96GXS                     2019                       1
# 1209   groSbUfkQngM                     2016                       1
# 1210   zmxGvIrOD0bt                     2015                       1
# 1211   rOmWFuJCud5G                     2018                       3
# 1212   k8HhHnnu2wmt                     2018                       3
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  0.0                            0
# ...

# %%
df_categorical_with_sols.describe()
# Out:
#        Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# count              1213.000000             1213.000000
# mean               2017.652102                2.014839
# std                   1.122522                1.135147
# min                2015.000000                1.000000
# 25%                2017.000000                1.000000
# 50%                2018.000000                1.000000
# 75%                2019.000000                3.000000
# max                2020.000000                4.000000
#
#        PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# count                       1202.000000                  1213.000000
# mean                           0.424293                     2.080791
# std                            0.687470                     3.164636
# min                            0.000000                     0.000000
# 25%                            0.000000                     0.000000
# ...

# %%
df_categorical_quant = pd.merge(df_categorical, df_quant , on ='participant_id', how ='inner')

# %%
df_categorical_quant
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      UmrK0vMLopoR                     2016                       1
# 1      CPaeQkhcjg7d                     2019                       3
# 2      Nb4EetVPm3gs                     2016                       1
# 3      p4vPhVu91o4b                     2018                       3
# 4      M09PXs7arQ5E                     2019                       3
# ...             ...                      ...                     ...
# 1208   Atx7oub96GXS                     2019                       1
# 1209   groSbUfkQngM                     2016                       1
# 1210   zmxGvIrOD0bt                     2015                       1
# 1211   rOmWFuJCud5G                     2018                       3
# 1212   k8HhHnnu2wmt                     2018                       3
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  0.0                            0
# ...

# %%
df_categorical_quant_matrices = pd.merge(df_categorical_quant, df_matrices , on ='participant_id', how ='inner')

# %%
df_categorical_quant_matrices
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      UmrK0vMLopoR                     2016                       1
# 1      CPaeQkhcjg7d                     2019                       3
# 2      Nb4EetVPm3gs                     2016                       1
# 3      p4vPhVu91o4b                     2018                       3
# 4      M09PXs7arQ5E                     2019                       3
# ...             ...                      ...                     ...
# 1208   Atx7oub96GXS                     2019                       1
# 1209   groSbUfkQngM                     2016                       1
# 1210   zmxGvIrOD0bt                     2015                       1
# 1211   rOmWFuJCud5G                     2018                       3
# 1212   k8HhHnnu2wmt                     2018                       3
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  0.0                            0
# ...

# %%
df_categorical_quant_matrices_with_sols = pd.merge(df_categorical_quant_matrices, df_solutions , on ='participant_id', how ='inner')

# %%
df_categorical_quant_matrices_with_sols
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      UmrK0vMLopoR                     2016                       1
# 1      CPaeQkhcjg7d                     2019                       3
# 2      Nb4EetVPm3gs                     2016                       1
# 3      p4vPhVu91o4b                     2018                       3
# 4      M09PXs7arQ5E                     2019                       3
# ...             ...                      ...                     ...
# 1208   Atx7oub96GXS                     2019                       1
# 1209   groSbUfkQngM                     2016                       1
# 1210   zmxGvIrOD0bt                     2015                       1
# 1211   rOmWFuJCud5G                     2018                       3
# 1212   k8HhHnnu2wmt                     2018                       3
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  0.0                            0
# ...

# %%
df_matrices_quant = pd.merge(df_matrices, df_quant, on ='participant_id', how ='inner')

# %%
df_matrices_quant.iloc[:,1:].describe()
# Out:
#        0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  0throw_4thcolumn  \
# count       1213.000000       1213.000000       1213.000000       1213.000000
# mean           0.060553          0.122315          0.060268          0.041287
# std            0.064178          0.054026          0.057495          0.043491
# min           -0.183279         -0.059932         -0.145566         -0.127827
# 25%            0.018482          0.086102          0.026548          0.014457
# 50%            0.058276          0.123220          0.061339          0.043246
# 75%            0.100103          0.154518          0.099056          0.068408
# max            0.321522          0.390895          0.278429          0.189825
#
#        0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  0throw_8thcolumn  \
# count       1213.000000       1213.000000       1213.000000       1213.000000
# mean           0.069722          0.091007          0.066852          0.000252
# ...

# %%
df_solutions.iloc[:,1]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1208    0
# 1209    0
# 1210    0
# 1211    0
# 1212    0
# Name: ADHD_Outcome, Length: 1213, dtype: int64

# %%
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer

# %%
# Identify columns with non-numeric values (non-numeric types)
non_numeric_columns = df.select_dtypes(exclude=[np.number]).columns
print("Columns with non-numeric values:", non_numeric_columns)

# %%
# Split into training and test sets
imputer = SimpleImputer(strategy='mean')
df_matrices_quant_imputed = imputer.fit_transform(df_matrices_quant[:,1:])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/datathon25/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(None, None, None), slice(1, None, None))
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[62], line 3
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df_matrices_quant_imputed, df_solutions.iloc[:,1], test_size=0.2, random_state=42)

# Create Ridge Regression model with regularization parameter alpha
ridge = Ridge(alpha=1.0)

# Fit the model
ridge.fit(X_train, y_train)

# %%
# Make predictions
y_pred = ridge.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
